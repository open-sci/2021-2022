# %% [markdown]
# # Open Science project 2021-22 personal diary

# %% [markdown]
# Personal notebook for Open Science course 2021-22

# %% [markdown]
# ## Team: Don't lock up

# %% [markdown]
# ### Mercoledì 31-03-2022

# %% [markdown]
# ### Giovedì 31-03-2022

# %% [markdown]
# <b>Topic of the day</b>: Open Methodology

# %% [markdown]
# * the steps involved in today lecture is discovery and analysis
# * we are going to discuss scientific workflow to maximise the reuse of methodologies and to foster the reproducibility of experiments

# %% [markdown]
# * #### Literature review
#     * For evaluating the existing literature you should create a convicing strategy for collecting all materials
# * #### Workflow
#     * for creating a workflow you can create a directed graph where each node is a step of the workflow

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The blue box are the input node.

# %% [markdown]
# This workflow is built for analyse corpus of scientific reaserches. It is a simple representation for obtain a certain output

# %% [markdown]
# ! PROBLEM ! you should matain the workflow. it may decay in a short period of time

# %% [markdown]
# * #### Crucial aspects for defining workflows
#     * example data inputs: also fake data, but close to the real one
#     * ...
